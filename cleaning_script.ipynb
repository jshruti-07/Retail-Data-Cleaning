# %%
import pandas as pd

# Load raw dataset
df = pd.read_csv("retail_raw.csv")

# Remove duplicates
df.drop_duplicates(inplace=True)

# Fix missing values
df["Price"] = df["Price"].fillna(df["Price"].median())

# Convert Date column
df["Date"] = pd.to_datetime(df["Date"])

# Remove outliers in Quantity
Q1 = df["Quantity"].quantile(0.25)
Q3 = df["Quantity"].quantile(0.75)
IQR = Q3 - Q1
df_clean = df[(df["Quantity"] >= Q1 - 1.5*IQR) & (df["Quantity"] <= Q3 + 1.5*IQR)]

# Save cleaned file
df_clean.to_csv("retail_cleaned.csv", index=False)

df_clean.head()
# Out:
#         Date  Product   Price  Quantity Customer
# 0 2024-01-01   Laptop   700.0         6        B
# 1 2024-01-02    Shoes  1200.0         8        B
# 2 2024-01-03  T-shirt  1500.0         2        A
# 3 2024-01-04  T-shirt  2000.0         4        C
# 4 2024-01-05  T-shirt  1200.0         6        C
